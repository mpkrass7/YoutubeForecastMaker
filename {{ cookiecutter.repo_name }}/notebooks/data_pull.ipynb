# %% [markdown]
# ### Make sure to put your credentials in conf/local/credentials.yml
#
# After credentials are set, set this notebook to run every hour. Don't run the notebook manually.

# %%
# !cd .. && kedro run -p "pull_data"
